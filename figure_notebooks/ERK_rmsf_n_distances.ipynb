# %%
import numpy as np
import matplotlib.pyplot as plt
import mdtraj as md
import seaborn as sns
sns.set_style('ticks')
import matplotlib.patches as mpatches

# %%
sns.set_context("notebook", rc={"lines.linewidth": 0.5})

# %%
rmsfs0 = np.load('rmsfs0.npy')
top = md.load('ERK1_WT.pdb')
top = top.atom_slice(top.top.select('name CA'))

rmsfs = rmsfs0
rmsfs0_res = []
rmsfs_res = rmsfs0_res

for traj_no in range(len(rmsfs)):

    rmsfs_res_ = []

    i = 0

    for residue in list(top.top.residues):
        no_atoms = len(list(residue.atoms))
        rmsfs_res_.append(np.mean(rmsfs[traj_no][i:i+no_atoms]))
        i += no_atoms
    
    rmsfs_res.append(rmsfs_res_)

# %%
rmsfs1 = np.load('rmsfs1.npy')
top = md.load('ERK1_74N.pdb')
top = top.atom_slice(top.top.select('name CA'))

rmsfs = rmsfs1
rmsfs1_res = []
rmsfs_res = rmsfs1_res

for traj_no in range(len(rmsfs)):

    rmsfs_res_ = []

    i = 0

    for residue in list(top.top.residues):
        no_atoms = len(list(residue.atoms))
        rmsfs_res_.append(np.mean(rmsfs[traj_no][i:i+no_atoms]))
        i += no_atoms
    
    rmsfs_res.append(rmsfs_res_)

# %%
rmsfs2 = np.load('rmsfs2.npy')
top = md.load('ERK2_WT.pdb')
top = top.atom_slice(top.top.select('name CA'))

rmsfs = rmsfs2
rmsfs2_res = []
rmsfs_res = rmsfs2_res

for traj_no in range(len(rmsfs)):

    rmsfs_res_ = []

    i = 0

    for residue in list(top.top.residues):
        no_atoms = len(list(residue.atoms))
        rmsfs_res_.append(np.mean(rmsfs[traj_no][i:i+no_atoms]))
        i += no_atoms
    
    rmsfs_res.append(rmsfs_res_)

# %%
rmsfs3 = np.load('rmsfs3.npy')
top = md.load('ERK2_55N.pdb')
top = top.atom_slice(top.top.select('name CA'))

rmsfs = rmsfs3
rmsfs3_res = []
rmsfs_res = rmsfs3_res

for traj_no in range(len(rmsfs)):

    rmsfs_res_ = []

    i = 0

    for residue in list(top.top.residues):
        no_atoms = len(list(residue.atoms))
        rmsfs_res_.append(np.mean(rmsfs[traj_no][i:i+no_atoms]))
        i += no_atoms
    
    rmsfs_res.append(rmsfs_res_)

# %%
rmsfs4 = np.load('rmsfs4.npy')
top = md.load('ERK2_Q102M.pdb')
top = top.atom_slice(top.top.select('name CA'))

rmsfs = rmsfs4
rmsfs4_res = []
rmsfs_res = rmsfs4_res

for traj_no in range(len(rmsfs)):

    rmsfs_res_ = []

    i = 0

    for residue in list(top.top.residues):
        no_atoms = len(list(residue.atoms))
        rmsfs_res_.append(np.mean(rmsfs[traj_no][i:i+no_atoms]))
        i += no_atoms
    
    rmsfs_res.append(rmsfs_res_)

# %%
rmsfs5 = np.load('rmsfs5.npy')
top = md.load('ERK2_55N_Q102M.pdb')
top = top.atom_slice(top.top.select('name CA'))

rmsfs = rmsfs5
rmsfs5_res = []
rmsfs_res = rmsfs5_res

for traj_no in range(len(rmsfs)):

    rmsfs_res_ = []

    i = 0

    for residue in list(top.top.residues):
        no_atoms = len(list(residue.atoms))
        rmsfs_res_.append(np.mean(rmsfs[traj_no][i:i+no_atoms]))
        i += no_atoms
    
    rmsfs_res.append(rmsfs_res_)

# %%
a = np.array(rmsfs0_res)[np.array([[x] for x in np.arange(len(rmsfs0_res))])]
b = np.array(rmsfs1_res)[np.array([[x] for x in np.arange(len(rmsfs1_res))])]

x0 = []
y0 = []

for i in range(len(a)):
    for j in range(len(a[i][0])):
        x0.append(j)
        y0.append(a[i][0][j]*10)

x1 = []
y1 = []

for i in range(len(b)):
    for j in range(len(b[i][0])):
        if j == 51:
            continue
        if j > 51:
            x1.append(j-1)
            y1.append(b[i][0][j]*10)
        else:
            x1.append(j)
            y1.append(b[i][0][j]*10)            

plt.figure(dpi=300)
sns.pointplot(x=x0, y=y0, markers='', errwidth=2, color='green', label='WT')
sns.pointplot(x=x1, y=y1, markers='', errwidth=2, color='blue', label='74N')
sns.pointplot(x=np.arange(352), y=(np.concatenate([np.mean(b, axis=0)[0][:51], np.mean(b, axis=0)[0][52:]])-np.mean(a, axis=0)[0])*10, markers='', errwidth=2, color='red')
plt.xticks(np.arange(0,len(rmsfs0_res[0]),50), np.arange(0,len(rmsfs0_res[0]),50))
plt.xlabel('Residue index')
plt.ylabel('RMSF ($\AA$)')
plt.ylim((-2,5))
plt.title('ERK1 74N')

patch1 = mpatches.Patch(color='green', label='WT')
patch2 = mpatches.Patch(color='blue', label='74N')
patch3 = mpatches.Patch(color='red', label='74N - WT')
plt.legend(handles=[patch1, patch2, patch3])

plt.tight_layout()
plt.show()

# %%
a = np.array(rmsfs2_res)[np.array([[x] for x in np.arange(len(rmsfs2_res))])]
b = np.array(rmsfs3_res)[np.array([[x] for x in np.arange(len(rmsfs3_res))])]

x0 = []
y0 = []

for i in range(len(a)):
    for j in range(len(a[i][0])):
        x0.append(j)
        y0.append(a[i][0][j]*10)

x1 = []
y1 = []

for i in range(len(b)):
    for j in range(len(b[i][0])):
        if j == 54:
            continue
        if j > 54:
            x1.append(j-1)
            y1.append(b[i][0][j]*10)
        else:
            x1.append(j)
            y1.append(b[i][0][j]*10)            

plt.figure(dpi=300)
sns.pointplot(x=x0, y=y0, markers='', errwidth=2, color='green', label='WT')
sns.pointplot(x=x1, y=y1, markers='', errwidth=2, color='blue', label='74N')
sns.pointplot(x=np.arange(357), y=(np.concatenate([np.mean(b, axis=0)[0][:54], np.mean(b, axis=0)[0][55:]])-np.mean(a, axis=0)[0])*10, markers='', errwidth=2, color='red')
plt.ylim((-2,5))
plt.xticks(np.arange(0,len(rmsfs2_res[0]),50), np.arange(0,len(rmsfs2_res[0]),50))
plt.xlabel('Residue index')
plt.ylabel('RMSF ($\AA$)')
plt.title('ERK2 55N')
plt.ylim((-2,5))

patch1 = mpatches.Patch(color='green', label='WT')
patch2 = mpatches.Patch(color='blue', label='55N')
patch3 = mpatches.Patch(color='red', label='55N - WT')
plt.legend(handles=[patch1, patch2, patch3])

plt.tight_layout()
plt.show()

# %%
a = np.array(rmsfs2_res)[np.array([[x] for x in np.arange(len(rmsfs2_res))])]
b = np.array(rmsfs4_res)[np.array([[x] for x in np.arange(len(rmsfs4_res))])]

x0 = []
y0 = []

for i in range(len(a)):
    for j in range(len(a[i][0])):
        x0.append(j)
        y0.append(a[i][0][j]*10)

x1 = []
y1 = []

for i in range(len(b)):
    for j in range(len(b[i][0])):
        if j == 54:
            continue
        if j > 54:
            x1.append(j-1)
            y1.append(b[i][0][j]*10)
        else:
            x1.append(j)
            y1.append(b[i][0][j]*10)            

plt.figure(dpi=300)
sns.pointplot(x=x0, y=y0, markers='', errwidth=2, color='green', label='WT')
sns.pointplot(x=x1, y=y1, markers='', errwidth=2, color='blue', label='74N')
sns.pointplot(x=np.arange(357), y=(np.concatenate([np.mean(b, axis=0)[0][:54], np.mean(b, axis=0)[0][54:]])-np.mean(a, axis=0)[0])*10, markers='', errwidth=2, color='red')
plt.ylim((-2,5))
plt.xticks(np.arange(0,len(rmsfs2_res[0]),50), np.arange(0,len(rmsfs2_res[0]),50))
plt.xlabel('Residue index')
plt.ylabel('RMSF ($\AA$)')
plt.title('ERK2 Q102M')

patch1 = mpatches.Patch(color='green', label='WT')
patch2 = mpatches.Patch(color='blue', label='Q102M')
patch3 = mpatches.Patch(color='red', label='Q102M - WT')
plt.legend(handles=[patch1, patch2, patch3], loc=1)

plt.tight_layout()
plt.show()

# %%
a = np.array(rmsfs2_res)[np.array([[x] for x in np.arange(len(rmsfs2_res))])]
b = np.array(rmsfs5_res)[np.array([[x] for x in np.arange(len(rmsfs5_res))])]

x0 = []
y0 = []

for i in range(len(a)):
    for j in range(len(a[i][0])):
        x0.append(j)
        y0.append(a[i][0][j]*10)

x1 = []
y1 = []

for i in range(len(b)):
    for j in range(len(b[i][0])):
        if j == 54:
            continue
        if j > 54:
            x1.append(j-1)
            y1.append(b[i][0][j]*10)
        else:
            x1.append(j)
            y1.append(b[i][0][j]*10)            

plt.figure(dpi=300)
sns.pointplot(x=x0, y=y0, markers='', errwidth=2, color='green', label='WT')
sns.pointplot(x=x1, y=y1, markers='', errwidth=2, color='blue', label='74N')
sns.pointplot(x=np.arange(357), y=(np.concatenate([np.mean(b, axis=0)[0][:54], np.mean(b, axis=0)[0][55:]])-np.mean(a, axis=0)[0])*10, markers='', errwidth=2, color='red')
plt.ylim((-2,5))
plt.xticks(np.arange(0,len(rmsfs2_res[0]),50), np.arange(0,len(rmsfs2_res[0]),50))
plt.xlabel('Residue index')
plt.ylabel('RMSF ($\AA$)')
plt.title('ERK2 55N-Q102M')

patch1 = mpatches.Patch(color='green', label='WT')
patch2 = mpatches.Patch(color='blue', label='55N-Q102M')
patch3 = mpatches.Patch(color='red', label='55N-Q102M - WT')
plt.legend(handles=[patch1, patch2, patch3])

plt.tight_layout()
plt.show()

# %%
distances0 = np.load('distances0_liam.npy')
dist0_concat = np.concatenate([distances0[i][0][100:] for i in range(len(distances0))])

distances1 = np.load('distances1_liam.npy')
dist1_concat = np.concatenate([distances1[i][0][100:] for i in range(len(distances1))])

distances2 = np.load('distances2_liam.npy')
dist2_concat = np.concatenate([distances2[i][0][100:] for i in range(len(distances2))])

distances3 = np.load('distances3_liam.npy')
dist3_concat = np.concatenate([distances3[i][0][100:] for i in range(len(distances3))])

distances4 = np.load('distances4_liam.npy')
dist4_concat = np.concatenate([distances4[i][0][100:] for i in range(len(distances4))])

distances5 = np.load('distances5_liam.npy')
dist5_concat = np.concatenate([distances5[i][0][100:] for i in range(len(distances5))])

# %%
# this is the order of the distances calculated:

# ERK2 numbering 
# For key catalytic residues mentioned in the manu

# E69-F166 
# K52-E69
# D165-K52

# For spines
# Regulatory spine:
# I84-L73
# L73-F166
# F166-H145
# H145-D208

# Catalytic spine:
# V37-A50
# A50-L154
# L153-L155 
# L153-M106 
# L155-M106
# M106-I215
# I215-M219

# %%
# only plotting those distances where at least one mutant is different from WT by 0.1 KS statistic in the KS test
# e.g.:

# %%
import scipy

# %%
dist = 0

scipy.stats.ks_2samp(dist0_concat[:,dist], dist1_concat[:,dist])
# Out:
# Ks_2sampResult(statistic=0.36495527524206139, pvalue=0.0)

# %%
sns.set_context("notebook")

# %%
dist = 0

plt.figure(dpi=200)
sns.distplot(dist0_concat[:,dist]*10, color='green')
sns.distplot(dist1_concat[:,dist]*10, color='blue')
plt.xlabel('E88-F185 distance ($\AA$)')
plt.ylabel('Probability density')
plt.xlim((2,10))
#plt.ylim((0,3))
plt.title('ERK1')

patch1 = mpatches.Patch(color='green', label='WT')
patch2 = mpatches.Patch(color='blue', label='74N')
plt.legend(handles=[patch1, patch2])

plt.show()

# %%
dist = 2

plt.figure(dpi=200)
sns.distplot(dist0_concat[:,dist]*10, color='green')
sns.distplot(dist1_concat[:,dist]*10, color='blue')
plt.xlabel('D184-K71 distance ($\AA$)')
plt.ylabel('Probability density')
plt.xlim((2,10))
#plt.ylim((0,3))
plt.title('ERK1')

patch1 = mpatches.Patch(color='green', label='WT')
patch2 = mpatches.Patch(color='blue', label='74N')
plt.legend(handles=[patch1, patch2])

plt.show()

# %%
dist = 4

plt.figure(dpi=200)
sns.distplot(dist0_concat[:,dist]*10, color='green')
sns.distplot(dist1_concat[:,dist]*10, color='blue')
plt.xlabel('L92-F185 distance ($\AA$)')
plt.ylabel('Probability density')
plt.xlim((2,10))
#plt.ylim((0,3))
plt.title('ERK1')

patch1 = mpatches.Patch(color='green', label='WT')
patch2 = mpatches.Patch(color='blue', label='74N')
plt.legend(handles=[patch1, patch2])

plt.show()

# %%
dist = 5

plt.figure(dpi=200)
sns.distplot(dist0_concat[:,dist]*10, color='green')
sns.distplot(dist1_concat[:,dist]*10, color='blue')
plt.xlabel('F185-H164 distance ($\AA$)')
plt.ylabel('Probability density')
plt.xlim((2,10))
#plt.ylim((0,3))
plt.title('ERK1')

patch1 = mpatches.Patch(color='green', label='WT')
patch2 = mpatches.Patch(color='blue', label='74N')
plt.legend(handles=[patch1, patch2])

plt.show()

# %%
dist = 8

plt.figure(dpi=200)
sns.distplot(dist0_concat[:,dist]*10, color='green')
sns.distplot(dist1_concat[:,dist]*10, color='blue')
plt.xlabel('A69-L173 distance ($\AA$)')
plt.ylabel('Probability density')
plt.xlim((2,10))
#plt.ylim((0,3))
plt.title('ERK1')

patch1 = mpatches.Patch(color='green', label='WT')
patch2 = mpatches.Patch(color='blue', label='74N')
plt.legend(handles=[patch1, patch2])

plt.show()

# %%
dist = 9

plt.figure(dpi=200)
sns.distplot(dist0_concat[:,dist]*10, color='green')
sns.distplot(dist1_concat[:,dist]*10, color='blue')
plt.xlabel('L172-L174 distance ($\AA$)')
plt.ylabel('Probability density')
plt.xlim((2,10))
#plt.ylim((0,3))
plt.title('ERK1')

patch1 = mpatches.Patch(color='green', label='WT')
patch2 = mpatches.Patch(color='blue', label='74N')
plt.legend(handles=[patch1, patch2])

plt.show()

# %%
dist = 0

plt.figure(dpi=200)
sns.distplot(dist2_concat[:,dist]*10, color='green')
sns.distplot(dist3_concat[:,dist]*10, color='blue')
sns.distplot(dist4_concat[:,dist]*10, color='yellow')
sns.distplot(dist5_concat[:,dist]*10, color='black')
plt.xlabel('E69-F166 distance ($\AA$)')
plt.ylabel('Probability density')
plt.xlim((2,10))
#plt.ylim((0,3))
plt.title('ERK2')

patch1 = mpatches.Patch(color='green', label='WT')
patch2 = mpatches.Patch(color='blue', label='55N')
patch3 = mpatches.Patch(color='yellow', label='Q102M')
patch4 = mpatches.Patch(color='black', label='55N-Q102M')
plt.legend(handles=[patch1, patch2, patch3, patch4])

plt.show()

# %%
dist = 1

plt.figure(dpi=200)
sns.distplot(dist2_concat[:,dist]*10, color='green')
sns.distplot(dist3_concat[:,dist]*10, color='blue')
sns.distplot(dist4_concat[:,dist]*10, color='yellow')
sns.distplot(dist5_concat[:,dist]*10, color='black')
plt.xlabel('K52-E69 distance ($\AA$)')
plt.ylabel('Probability density')
plt.xlim((2,10))
#plt.ylim((0,3))
plt.title('ERK2')

patch1 = mpatches.Patch(color='green', label='WT')
patch2 = mpatches.Patch(color='blue', label='55N')
patch3 = mpatches.Patch(color='yellow', label='Q102M')
patch4 = mpatches.Patch(color='black', label='55N-Q102M')
plt.legend(handles=[patch1, patch2, patch3, patch4])

plt.show()

# %%
dist = 2

plt.figure(dpi=200)
sns.distplot(dist2_concat[:,dist]*10, color='green')
sns.distplot(dist3_concat[:,dist]*10, color='blue')
sns.distplot(dist4_concat[:,dist]*10, color='yellow')
sns.distplot(dist5_concat[:,dist]*10, color='black')
plt.xlabel('D165-K52 distance ($\AA$)')
plt.ylabel('Probability density')
plt.xlim((2,10))
#plt.ylim((0,3))
plt.title('ERK2')

patch1 = mpatches.Patch(color='green', label='WT')
patch2 = mpatches.Patch(color='blue', label='55N')
patch3 = mpatches.Patch(color='yellow', label='Q102M')
patch4 = mpatches.Patch(color='black', label='55N-Q102M')
plt.legend(handles=[patch1, patch2, patch3, patch4])

plt.show()

# %%
dist = 7

plt.figure(dpi=200)
sns.distplot(dist2_concat[:,dist]*10, color='green')
sns.distplot(dist3_concat[:,dist]*10, color='blue')
sns.distplot(dist4_concat[:,dist]*10, color='yellow')
sns.distplot(dist5_concat[:,dist]*10, color='black')
plt.xlabel('V37-A50 distance ($\AA$)')
plt.ylabel('Probability density')
plt.xlim((2,10))
#plt.ylim((0,3))
plt.title('ERK2')

patch1 = mpatches.Patch(color='green', label='WT')
patch2 = mpatches.Patch(color='blue', label='55N')
patch3 = mpatches.Patch(color='yellow', label='Q102M')
patch4 = mpatches.Patch(color='black', label='55N-Q102M')
plt.legend(handles=[patch1, patch2, patch3, patch4])

plt.show()

# %%
dist = 8

plt.figure(dpi=200)
sns.distplot(dist2_concat[:,dist]*10, color='green')
sns.distplot(dist3_concat[:,dist]*10, color='blue')
sns.distplot(dist4_concat[:,dist]*10, color='yellow')
sns.distplot(dist5_concat[:,dist]*10, color='black')
plt.xlabel('A50-L154 distance ($\AA$)')
plt.ylabel('Probability density')
plt.xlim((4,12))
#plt.ylim((0,3))
plt.title('ERK2')

patch1 = mpatches.Patch(color='green', label='WT')
patch2 = mpatches.Patch(color='blue', label='55N')
patch3 = mpatches.Patch(color='yellow', label='Q102M')
patch4 = mpatches.Patch(color='black', label='55N-Q102M')
plt.legend(handles=[patch1, patch2, patch3, patch4])

plt.show()

# %%
dist = 12

plt.figure(dpi=200)
sns.distplot(dist2_concat[:,dist]*10, color='green')
sns.distplot(dist3_concat[:,dist]*10, color='blue')
sns.distplot(dist4_concat[:,dist]*10, color='yellow')
sns.distplot(dist5_concat[:,dist]*10, color='black')
plt.xlabel('M106-I215 distance ($\AA$)')
plt.ylabel('Probability density')
plt.xlim((12,18))
#plt.ylim((0,3))
plt.title('ERK2')

patch1 = mpatches.Patch(color='green', label='WT')
patch2 = mpatches.Patch(color='blue', label='55N')
patch3 = mpatches.Patch(color='yellow', label='Q102M')
patch4 = mpatches.Patch(color='black', label='55N-Q102M')
plt.legend(handles=[patch1, patch2, patch3, patch4])

plt.show()
